# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %%
age = pd.read_csv('age_subset.csv')
age.head()
# Out:
#    Unnamed: 0    GISJOIN  YEAR    STATE       PLACE           GEOID     Total  \
# 0           0  G01003076  2019  Alabama      Auburn  16000US0103076   66254.0
# 1           1  G01007000  2019  Alabama  Birmingham  16000US0107000  210080.0
# 2           2  G01021184  2019  Alabama      Dothan  16000US0121184   68522.0
# 3           3  G01035896  2019  Alabama      Hoover  16000US0135896   85772.0
# 4           4  G01037000  2019  Alabama  Huntsville  16000US0137000  201594.0
#
#       Male  m_19_under  m_20_24  ...  m_55_64  m_65_up    Female  f_19_under  \
# 0  33634.0      9932.0   6827.0  ...   1738.0   2749.0   32620.0      9203.0
# 1  98939.0     24936.0   7506.0  ...  13149.0  12690.0  111141.0     21122.0
# 2  33029.0      8748.0   1952.0  ...   4177.0   5530.0   35493.0      7370.0
# 3  40719.0      9738.0   2269.0  ...   3616.0   6451.0   45053.0     12398.0
# 4  96741.0     23438.0   8720.0  ...  11782.0  14584.0  104853.0     23359.0
#
# ...

# %%
cities = gpd.read_file('Desktop/git/USA_Major_Cities/0c5a2fa1-3463-4fc7-99e5-e206023a7e682020313-1-nmlntc.mln9c.shp')
cities.head()
# Out:
#    FID        NAME CLASS  ST STFIPS PLACEFIPS CAPITAL  POP_CLASS  POPULATION  \
# 0    1       Ammon  city  ID     16   1601990    None          6       15181
# 1    2   Blackfoot  city  ID     16   1607840    None          6       11946
# 2    3  Boise City  city  ID     16   1608830   State          8      225405
# 3    4      Burley  city  ID     16   1611260    None          6       10727
# 4    5    Caldwell  city  ID     16   1612250    None          7       53942
#
#    POP2010  ...  MARHH_NO_C  MHH_CHILD  FHH_CHILD  FAMILIES  AVE_FAM_SZ  \
# 0    13816  ...        1131        106        335      3352        3.61
# 1    11899  ...        1081        174        381      2958        3.31
# 2   205671  ...       21233       2414       5919     50647        2.97
# 3    10345  ...         861        139        358      2499        3.37
# 4    46237  ...        3113        686       1755     10776        3.51
#
# ...

# %%
print(cities.crs)
# Out:
# epsg:4326

# %%
cities.loc[0,'geometry']

# %%
cities.plot();

# %%
fig, ax = plt.subplots(figsize = (36, 14))
cities.plot(column = 'POPULATION',
                cmap = 'Blues',
                edgecolor = 'black',
                legend = True,
                ax = ax)
plt.title('Population of Cities', fontsize = 14)
ax.axis('off');
