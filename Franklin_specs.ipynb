# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
franklin_stats = pd.read_csv('Desktop/git/Admin_Stats_Franklin.csv')
franklin_stats.tail()
# Out:
#               Date & Time  Fiscal Year  \
# 5  06/30/2016 12:00:00 AM         2016
# 6  06/30/2017 12:00:00 AM         2017
# 7  06/30/2018 12:00:00 AM         2018
# 8  06/30/2019 12:00:00 AM         2019
# 9  06/30/2020 12:00:00 AM         2020
#
#    90% or better of citizens who consider Franklin's quality of life to be excellent/good  \
# 5                                               97.0
# 6                                               97.0
# 7                                               97.0
# 8                                               97.0
# 9                                               97.0
#
#    Franklin will seek to improve housing diversity as identified through the 2013 Housing Analysis  \
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# ...

# %%
franklin_eco = pd.read_csv('Desktop/git/Eco_Devo_Stats_Franklin.csv')
franklin_eco.tail()
# Out:
#                Date & Time  Fiscal Year  Cost of Living Index  \
# 10  06/30/2016 12:00:00 AM         2016                  95.7
# 11  06/30/2017 12:00:00 AM         2017                  96.0
# 12  06/30/2018 12:00:00 AM         2018                  98.0
# 13  06/30/2019 12:00:00 AM         2019                  99.0
# 14  06/30/2020 12:00:00 AM         2020                  99.0
#
#     Best Cities for Start-up Businesses in USA   \
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
#
#     Tourists Visits to Franklin Sites  Revenue Generated by Hotel/Motel Tax  \
# 10                          1430000.0                               3557971
# 11                          1510000.0                               3710589
# ...

# %%
franklin_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                           --------------  -----
#  0   Date & Time                                                                                      10 non-null     object
#  1   Fiscal Year                                                                                      10 non-null     int64
#  2   90% or better of citizens who consider Franklin's quality of life to be excellent/good           9 non-null      float64
#  3   Franklin will seek to improve housing diversity as identified through the 2013 Housing Analysis  0 non-null      float64
#  4   Franklin Ranking - 100 Best Places to live in U.S.                                               9 non-null      float64
# ...

# %%
franklin_eco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 22 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Date & Time                                                 15 non-null     object
#  1   Fiscal Year                                                 15 non-null     int64
#  2   Cost of Living Index                                        7 non-null      float64
#  3   Best Cities for Start-up Businesses in USA                  3 non-null      float64
#  4   Tourists Visits to Franklin Sites                           8 non-null      float64
#  5   Revenue Generated by Hotel/Motel Tax                        15 non-null     int64
#  6   Franklin Collections (in $ millions)                        15 non-null     int64
# ...
